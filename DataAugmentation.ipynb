# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.9

# %%
import tensorflow as tf
print(f'Tensorflow version currently used is {tf.__version__}')
# Out:
# Tensorflow version currently used is 2.4.0

# %%
import keras
print(f'Keras version currently used is {keras.__version__}')
# Out:
# Keras version currently used is 2.4.3

# %%
import keras
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %%
# create image data augmentation generator
datagen = ImageDataGenerator(
    rotation_range=60,
    width_shift_range=0,
    height_shift_range=0,
    shear_range=0,
    zoom_range=0,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='wrap')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reads the image and resizes it
img = image.load_img('/content/drive/My Drive/cat.jpg',target_size=(150, 150))

# %%
# Converts into a Numpy array with shape (150,150,3)
x = image.img_to_array(img)
print(x.shape)
# Out:
# (150, 150, 3)

# %%
# Reshapes it to (1,150,150,3)

x = x.reshape((1,) + x.shape)
print("+++++++++++++After reshaping +++++++++++++++++++++")
print(x.shape)
# Out:
# +++++++++++++After reshaping +++++++++++++++++++++
# (1, 150, 150, 3)

# %%
#Generates batches of randomly transformed images
i = 0
for batch in datagen.flow(x, batch_size=1, save_to_dir='/content/drive/My Drive/Test_Data', save_prefix='cat'):
    i += 1
    if i % 8 == 0:
        break
